# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# df.drop(columns=['Unnamed:0'])
df.head()
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(df['Price'])
# Out:
# C:\Users\DIVYA METHWANI\AppData\Local\Temp\ipykernel_18744\816203730.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\DIVYA METHWANI\AppData\Local\Temp\ipykernel_18744\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company     TypeName  Inches  \
# 249    Apple    Ultrabook    13.3
# 1111    Dell     Notebook    15.6
# 600       HP     Notebook    15.6
# 452       HP  Workstation    15.6
# 1154    Dell     Notebook    15.6
#
#                                    ScreenResolution  \
# 249              IPS Panel Retina Display 2560x1600
# 1111                                       1366x768
# 600                               Full HD 1920x1080
# 452                     IPS Panel Full HD 1920x1080
# 1154  IPS Panel Touchscreen / 4K Ultra HD 3840x2160
#
#                               Cpu  Ram     Memory  \
# 249          Intel Core i5 3.1GHz    8  512GB SSD
# 1111   Intel Core i5 6200U 2.3GHz    4  500GB HDD
# 600    Intel Core i7 7500U 2.7GHz    8  256GB SSD
# 452   Intel Core i7 7820HQ 2.9GHz    8  512GB SSD
# 1154  Intel Core i5 6300HQ 2.3GHz    8  256GB SSD
#
#                                Gpu       OpSys  Weight        Price  \
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]

# %%
df.head()
df.sample(5)
# Out:
#      Company   TypeName  Inches                  ScreenResolution  \
# 335       HP   Notebook    14.0                 Full HD 1920x1080
# 198       HP     Gaming    17.3       IPS Panel Full HD 1920x1080
# 358     Dell   Notebook    15.6              Touchscreen 1366x768
# 543     Acer     Gaming    15.6                 Full HD 1920x1080
# 1188    Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                               Cpu  Ram                Memory  \
# 335    Intel Core i5 7300U 2.6GHz    8             256GB SSD
# 198   Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 358    Intel Core i5 7200U 2.5GHz    8               2TB HDD
# 543   Intel Core i5 7300HQ 2.5GHz    8               1TB HDD
# 1188   Intel Core i5 6300U 2.4GHz    8             256GB SSD
#
#                           Gpu       OpSys  Weight       Price  Touchscreen  \
# 335     Intel HD Graphics 620  Windows 10    1.48  67559.0400            0
# ...

# %%
df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['X_res']=df['X_res'].astype('int')
df['Y_res']=df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
# df.corr()['Price']
numeric_df = df.select_dtypes(include=[np.number])
correlation_with_price = numeric_df.corr()['Price']
print(correlation_with_price)
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi']=(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
# df.corr()['Price']

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_with_price = numeric_df.corr()['Price']
print(correlation_with_price)
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS  X_res  Y_res         ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu name
# ...

# %%
def fetch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other intel processor'
        else:
            return 'AMD processor'

# %%
df['Cpu brand']=df['Cpu name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu name']).inplace=True
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu name      Cpu brand
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# Convert the 'Memory' column to a string and remove '.0' if present
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)

# Remove 'GB' and 'TB' from the 'Memory' column, replace 'TB' with '000' to convert TB to GB
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')

# Split the 'Memory' column into two columns at the '+' symbol
new = df['Memory'].str.split("+", n=1, expand=True)

# Strip any extra whitespace
df['first'] = new[0].str.strip()
df['second'] = new[1].str.strip()

# Fill NaN values in 'second' with '0'
df['second'].fillna("0", inplace=True)

# Remove all non-numeric characters from 'first' and 'second' columns
df['first'] = df['first'].str.replace(r'\D', '', regex=True)
df['second'] = df['second'].str.replace(r'\D', '', regex=True)

# Convert the cleaned 'first' and 'second' columns to integers
df['first'] = df['first'].astype(int)
df['second'] = df['second'].astype(int)

# Create binary columns indicating the type of storage in 'first' and 'second'
df["Layer1HDD"] = new[0].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = new[0].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = new[0].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = new[0].apply(lambda x: 1 if "Flash storage" in x else 0)

# Handle None values in new[1] before applying lambda
df["Layer2HDD"] = new[1].apply(lambda x: 1 if x is not None and "HDD" in x else 0)
df["Layer2SSD"] = new[1].apply(lambda x: 1 if x is not None and "SSD" in x else 0)
df["Layer2Hybrid"] = new[1].apply(lambda x: 1 if x is not None and "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = new[1].apply(lambda x: 1 if x is not None and "Flash storage" in x else 0)

# Calculate the total storage for each type
df["HDD"] = df["first"] * df['Layer1HDD'] + df['second'] * df['Layer2HDD']
df["SSD"] = df["first"] * df['Layer1SSD'] + df['second'] * df['Layer2SSD']
df["Hybrid"] = df["first"] * df['Layer1Hybrid'] + df['second'] * df['Layer2Hybrid']
df["Flash_Storage"] = df["first"] * df['Layer1Flash_Storage'] + df['second'] * df['Layer2Flash_Storage']

# Drop the intermediate columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'], inplace=True)

print(df.head())
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
df.drop(columns='Memory')
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
# df.corr()['price']

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Get the correlation values for the 'Price' column
price_correlation = correlation_matrix['Price']

print(price_correlation)
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage         NaN
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'])
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand']=df['Gpu'].apply(lambda x:x.split()[0])
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df['Gpu brand']!='ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi       Cpu name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#        Cpu brand  HDD  SSD  Hybrid  Flash_Storage Gpu brand
# ...

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi       Cpu name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#        Cpu brand  HDD  SSD  Hybrid  Flash_Storage Gpu brand
# ...

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp=='Windows 10' or inp == 'Windows 7' or inp=='Windows 10 s':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'Other/no os/Linus'

# %%
df['os']=df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram             Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128 SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512 SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256 SSD
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi       Cpu name  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
# ...

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\DIVYA METHWANI\AppData\Local\Temp\ipykernel_18744\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Get the correlation values for the 'Price' column
price_correlation = correlation_matrix['Price']

print(price_correlation)
# Out:
# Ram              0.742905
# Weight           0.209867
# Price            1.000000
# Touchscreen      0.192917
# IPS              0.253320
# ppi              0.475368
# HDD             -0.096891
# SSD              0.670660
# Hybrid           0.007942
# Flash_Storage         NaN
# Name: Price, dtype: float64

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\DIVYA METHWANI\AppData\Local\Temp\ipykernel_18744\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# X=df.drop(columns=['Price'])
# y=np.log(df['Price'])
# X

# %%
# y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
df["Company"].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        8
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
{i:key for key , i in enumerate(list(df['Company'].unique()))}
# Out:
# {'Apple': 0,
#  'HP': 1,
#  'Acer': 2,
#  'Asus': 3,
#  'Dell': 4,
#  'Lenovo': 5,
#  'Chuwi': 6,
#  'MSI': 7,
#  'Microsoft': 8,
#  'Toshiba': 9,
#  'Huawei': 10,
#  'Xiaomi': 11,
#  'Vero': 12,
#  'Razer': 13,
#  'Mediacom': 14,
#  'Samsung': 15,
#  'Google': 16,
#  'Fujitsu': 17,
#  'LG': 18}

# %%
dt = {'Apple': 0,
 'HP': 1,
 'Acer': 2,
 'Asus': 3,
 'Dell': 4,
 'Lenovo': 5,
 'Chuwi': 6,
 'MSI': 7,
 'Microsoft': 8,
 'Toshiba': 9,
 'Huawei': 10,
 'Xiaomi': 11,
 'Vero': 12,
 'Razer': 13,
 'Mediacom': 14,
 'Samsung': 15,
 'Google': 16,
 'Fujitsu': 17,
 'LG': 18}

# %%
df['Company'] = df['Company'].map(dt)

# %%
# X=df.drop(columns=['Price'])
# y=np.log(df['Price'])
# X

# %%
# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
df["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    120
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
{i:key for key , i in enumerate(list(df['TypeName'].unique()))}
# Out:
# {'Ultrabook': 0,
#  'Notebook': 1,
#  'Netbook': 2,
#  'Gaming': 3,
#  '2 in 1 Convertible': 4,
#  'Workstation': 5}

# %%
dt1 = {'Ultrabook': 0,
 'Notebook': 1,
 'Netbook': 2,
 'Gaming': 3,
 '2 in 1 Convertible': 4,
 'Workstation': 5}

# %%
df['TypeName'] = df['TypeName'].map(dt1)

# %%
df.head()
# Out:
#    Company  TypeName                         Cpu  Ram             Memory  \
# 0        0         0        Intel Core i5 2.3GHz    8            128 SSD
# 1        0         0        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2        1         1  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3        0         0        Intel Core i7 2.7GHz   16            512 SSD
# 4        0         0        Intel Core i5 3.1GHz    8            256 SSD
#
#    Weight        Price  Touchscreen  IPS         ppi       Cpu name  \
# 0    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#        Cpu brand  HDD  SSD  Hybrid  Flash_Storage Gpu brand                 os
# ...

# %%
{i:key for key , i in enumerate(list(df['Cpu'].unique()))}
# Out:
# {'Intel Core i5 2.3GHz': 0,
#  'Intel Core i5 1.8GHz': 1,
#  'Intel Core i5 7200U 2.5GHz': 2,
#  'Intel Core i7 2.7GHz': 3,
#  'Intel Core i5 3.1GHz': 4,
#  'AMD A9-Series 9420 3GHz': 5,
#  'Intel Core i7 2.2GHz': 6,
#  'Intel Core i7 8550U 1.8GHz': 7,
#  'Intel Core i5 8250U 1.6GHz': 8,
#  'Intel Core i3 6006U 2GHz': 9,
#  'Intel Core i7 2.8GHz': 10,
#  'Intel Core M m3 1.2GHz': 11,
#  'Intel Core i7 7500U 2.7GHz': 12,
#  'Intel Core i7 2.9GHz': 13,
#  'Intel Core i3 7100U 2.4GHz': 14,
#  'Intel Atom x5-Z8350 1.44GHz': 15,
#  'Intel Core i5 7300HQ 2.5GHz': 16,
#  'AMD E-Series E2-9000e 1.5GHz': 17,
#  'Intel Core i5 1.6GHz': 18,
#  'Intel Core i7 8650U 1.9GHz': 19,
#  'Intel Atom x5-Z8300 1.44GHz': 20,
#  'AMD E-Series E2-6110 1.5GHz': 21,
#  'AMD A6-Series 9220 2.5GHz': 22,
#  'Intel Celeron Dual Core N3350 1.1GHz': 23,
#  'Intel Core i3 7130U 2.7GHz': 24,
#  'Intel Core i7 7700HQ 2.8GHz': 25,
#  'Intel Core i5 2.0GHz': 26,
#  'AMD Ryzen 1700 3GHz': 27,
# ...

# %%
dt2= {'Intel Core i5 2.3GHz': 0,
 'Intel Core i5 1.8GHz': 1,
 'Intel Core i5 7200U 2.5GHz': 2,
 'Intel Core i7 2.7GHz': 3,
 'Intel Core i5 3.1GHz': 4,
 'AMD A9-Series 9420 3GHz': 5,
 'Intel Core i7 2.2GHz': 6,
 'Intel Core i7 8550U 1.8GHz': 7,
 'Intel Core i5 8250U 1.6GHz': 8,
 'Intel Core i3 6006U 2GHz': 9,
 'Intel Core i7 2.8GHz': 10,
 'Intel Core M m3 1.2GHz': 11,
 'Intel Core i7 7500U 2.7GHz': 12,
 'Intel Core i7 2.9GHz': 13,
 'Intel Core i3 7100U 2.4GHz': 14,
 'Intel Atom x5-Z8350 1.44GHz': 15,
 'Intel Core i5 7300HQ 2.5GHz': 16,
 'AMD E-Series E2-9000e 1.5GHz': 17,
 'Intel Core i5 1.6GHz': 18,
 'Intel Core i7 8650U 1.9GHz': 19,
 'Intel Atom x5-Z8300 1.44GHz': 20,
 'AMD E-Series E2-6110 1.5GHz': 21,
 'AMD A6-Series 9220 2.5GHz': 22,
 'Intel Celeron Dual Core N3350 1.1GHz': 23,
 'Intel Core i3 7130U 2.7GHz': 24,
 'Intel Core i7 7700HQ 2.8GHz': 25,
 'Intel Core i5 2.0GHz': 26,
 'AMD Ryzen 1700 3GHz': 27,
 'Intel Pentium Quad Core N4200 1.1GHz': 28,
 'Intel Atom x5-Z8550 1.44GHz': 29,
 'Intel Celeron Dual Core N3060 1.6GHz': 30,
 'Intel Core i5 1.3GHz': 31,
 'AMD FX 9830P 3GHz': 32,
 'Intel Core i7 7560U 2.4GHz': 33,
 'AMD E-Series 6110 1.5GHz': 34,
 'Intel Core i5 6200U 2.3GHz': 35,
 'Intel Core M 6Y75 1.2GHz': 36,
 'Intel Core i5 7500U 2.7GHz': 37,
 'Intel Core i3 6006U 2.2GHz': 38,
 'AMD A6-Series 9220 2.9GHz': 39,
 'Intel Core i7 6920HQ 2.9GHz': 40,
 'Intel Core i5 7Y54 1.2GHz': 41,
 'Intel Core i7 7820HK 2.9GHz': 42,
 'Intel Xeon E3-1505M V6 3GHz': 43,
 'Intel Core i7 6500U 2.5GHz': 44,
 'AMD E-Series 9000e 1.5GHz': 45,
 'AMD A10-Series A10-9620P 2.5GHz': 46,
 'AMD A6-Series A6-9220 2.5GHz': 47,
 'Intel Core i5 2.9GHz': 48,
 'Intel Core i7 6600U 2.6GHz': 49,
 'Intel Core i3 6006U 2.0GHz': 50,
 'Intel Celeron Dual Core 3205U 1.5GHz': 51,
 'Intel Core i7 7820HQ 2.9GHz': 52,
 'AMD A10-Series 9600P 2.4GHz': 53,
 'Intel Core i7 7600U 2.8GHz': 54,
 'AMD A8-Series 7410 2.2GHz': 55,
 'Intel Celeron Dual Core 3855U 1.6GHz': 56,
 'Intel Pentium Quad Core N3710 1.6GHz': 57,
 'AMD A12-Series 9720P 2.7GHz': 58,
 'Intel Core i5 7300U 2.6GHz': 59,
 'AMD A12-Series 9720P 3.6GHz': 60,
 'Intel Celeron Quad Core N3450 1.1GHz': 61,
 'Intel Celeron Dual Core N3060 1.60GHz': 62,
 'Intel Core i5 6440HQ 2.6GHz': 63,
 'Intel Core i7 6820HQ 2.7GHz': 64,
 'AMD Ryzen 1600 3.2GHz': 65,
 'Intel Core i7 7Y75 1.3GHz': 66,
 'Intel Core i5 7440HQ 2.8GHz': 67,
 'Intel Core i7 7660U 2.5GHz': 68,
 'Intel Core i7 7700HQ 2.7GHz': 69,
 'Intel Core M m3-7Y30 2.2GHz': 70,
 'Intel Core i5 7Y57 1.2GHz': 71,
 'Intel Core i7 6700HQ 2.6GHz': 72,
 'Intel Core i3 6100U 2.3GHz': 73,
 'AMD A10-Series 9620P 2.5GHz': 74,
 'AMD E-Series 7110 1.8GHz': 75,
 'Intel Celeron Dual Core N3350 2.0GHz': 76,
 'AMD A9-Series A9-9420 3GHz': 77,
 'Intel Core i7 6820HK 2.7GHz': 78,
 'Intel Core M 7Y30 1.0GHz': 79,
 'Intel Xeon E3-1535M v6 3.1GHz': 80,
 'Intel Celeron Quad Core N3160 1.6GHz': 81,
 'Intel Core i5 6300U 2.4GHz': 82,
 'Intel Core i3 6100U 2.1GHz': 83,
 'AMD E-Series E2-9000 2.2GHz': 84,
 'Intel Celeron Dual Core N3050 1.6GHz': 85,
 'Intel Core M M3-6Y30 0.9GHz': 86,
 'AMD A9-Series 9420 2.9GHz': 87,
 'Intel Core i5 6300HQ 2.3GHz': 88,
 'AMD A6-Series 7310 2GHz': 89,
 'Intel Atom Z8350 1.92GHz': 90,
 'Intel Xeon E3-1535M v5 2.9GHz': 91,
 'Intel Core i5 6260U 1.8GHz': 92,
 'Intel Pentium Dual Core N4200 1.1GHz': 93,
 'Intel Celeron Quad Core N3710 1.6GHz': 94,
 'Intel Core M 1.2GHz': 95,
 'AMD A12-Series 9700P 2.5GHz': 96,
 'Intel Core i7 7500U 2.5GHz': 97,
 'Intel Pentium Dual Core 4405U 2.1GHz': 98,
 'AMD A4-Series 7210 2.2GHz': 99,
 'Intel Core i7 6560U 2.2GHz': 100,
 'Intel Core M m7-6Y75 1.2GHz': 101,
 'AMD FX 8800P 2.1GHz': 102,
 'Intel Core M M7-6Y75 1.2GHz': 103,
 'Intel Core i5 7200U 2.50GHz': 104,
 'Intel Core i5 7200U 2.70GHz': 105,
 'Intel Atom X5-Z8350 1.44GHz': 106,
 'Intel Core i5 7200U 2.7GHz': 107,
 'Intel Core M 1.1GHz': 108,
 'Intel Pentium Dual Core 4405Y 1.5GHz': 109,
 'Intel Pentium Quad Core N3700 1.6GHz': 110,
 'Intel Core M 6Y54 1.1GHz': 111,
 'Intel Core i7 6500U 2.50GHz': 112,
 'Intel Celeron Dual Core N3350 2GHz': 113,
 'AMD E-Series 9000 2.2GHz': 114,
 'Intel Core M 6Y30 0.9GHz': 115,
 'AMD A9-Series 9410 2.9GHz': 116}

# %%
df['Cpu'] = df['Cpu'].map(dt2)

# %%
df.head()
# Out:
#    Company  TypeName  Cpu  Ram             Memory  Weight        Price  \
# 0        0         0    0    8            128 SSD    1.37   71378.6832
# 1        0         0    1    8  128 Flash Storage    1.34   47895.5232
# 2        1         1    2    8            256 SSD    1.86   30636.0000
# 3        0         0    3   16            512 SSD    1.83  135195.3360
# 4        0         0    4    8            256 SSD    1.37   96095.8080
#
#    Touchscreen  IPS         ppi       Cpu name      Cpu brand  HDD  SSD  \
# 0            0    1  226.983005  Intel Core i5  Intel Core i5    0  128
# 1            0    0  127.677940  Intel Core i5  Intel Core i5    0    0
# 2            0    0  141.211998  Intel Core i5  Intel Core i5    0  256
# 3            0    1  220.534624  Intel Core i7  Intel Core i7    0  512
# 4            0    1  226.983005  Intel Core i5  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage Gpu brand                 os
# ...

# %%
{i:key for key , i in enumerate(list(df['Memory'].unique()))}
# Out:
# {'128 SSD': 0,
#  '128 Flash Storage': 1,
#  '256 SSD': 2,
#  '512 SSD': 3,
#  '500 HDD': 4,
#  '256 Flash Storage': 5,
#  '1000 HDD': 6,
#  '32 Flash Storage': 7,
#  '128 SSD +  1000 HDD': 8,
#  '256 SSD +  256 SSD': 9,
#  '64 Flash Storage': 10,
#  '256 SSD +  1000 HDD': 11,
#  '256 SSD +  2000 HDD': 12,
#  '32 SSD': 13,
#  '2000 HDD': 14,
#  '64 SSD': 15,
#  '1000 Hybrid': 16,
#  '512 SSD +  1000 HDD': 17,
#  '1000 SSD': 18,
#  '256 SSD +  500 HDD': 19,
#  '128 SSD +  2000 HDD': 20,
#  '512 SSD +  512 SSD': 21,
#  '16 SSD': 22,
#  '16 Flash Storage': 23,
#  '512 SSD +  256 SSD': 24,
#  '512 SSD +  2000 HDD': 25,
#  '64 Flash Storage +  1000 HDD': 26,
#  '180 SSD': 27,
#  '1000 HDD +  1000 HDD': 28,
#  '32 HDD': 29,
#  '1000 SSD +  1000 HDD': 30,
#  '512 Flash Storage': 31,
#  '128 HDD': 32,
#  '240 SSD': 33,
#  '8 SSD': 34,
#  '508 Hybrid': 35,
#  '512 SSD +  1000 Hybrid': 36,
#  '256 SSD +  1000 Hybrid': 37}

# %%
dt3 = {'128 SSD': 0,
 '128 Flash Storage': 1,
 '256 SSD': 2,
 '512 SSD': 3,
 '500 HDD': 4,
 '256 Flash Storage': 5,
 '1000 HDD': 6,
 '32 Flash Storage': 7,
 '128 SSD +  1000 HDD': 8,
 '256 SSD +  256 SSD': 9,
 '64 Flash Storage': 10,
 '256 SSD +  1000 HDD': 11,
 '256 SSD +  2000 HDD': 12,
 '32 SSD': 13,
 '2000 HDD': 14,
 '64 SSD': 15,
 '1000 Hybrid': 16,
 '512 SSD +  1000 HDD': 17,
 '1000 SSD': 18,
 '256 SSD +  500 HDD': 19,
 '128 SSD +  2000 HDD': 20,
 '512 SSD +  512 SSD': 21,
 '16 SSD': 22,
 '16 Flash Storage': 23,
 '512 SSD +  256 SSD': 24,
 '512 SSD +  2000 HDD': 25,
 '64 Flash Storage +  1000 HDD': 26,
 '180 SSD': 27,
 '1000 HDD +  1000 HDD': 28,
 '32 HDD': 29,
 '1000 SSD +  1000 HDD': 30,
 '512 Flash Storage': 31,
 '128 HDD': 32,
 '240 SSD': 33,
 '8 SSD': 34,
 '508 Hybrid': 35,
 '512 SSD +  1000 Hybrid': 36,
 '256 SSD +  1000 Hybrid': 37}

# %%
df["Memory"] = df['Memory'].map(dt3)

# %%
df.head()
# Out:
#    Company  TypeName  Cpu  Ram  Memory  Weight        Price  Touchscreen  IPS  \
# 0        0         0    0    8       0    1.37   71378.6832            0    1
# 1        0         0    1    8       1    1.34   47895.5232            0    0
# 2        1         1    2    8       2    1.86   30636.0000            0    0
# 3        0         0    3   16       3    1.83  135195.3360            0    1
# 4        0         0    4    8       2    1.37   96095.8080            0    1
#
#           ppi       Cpu name      Cpu brand  HDD  SSD  Hybrid  Flash_Storage  \
# 0  226.983005  Intel Core i5  Intel Core i5    0  128       0              0
# 1  127.677940  Intel Core i5  Intel Core i5    0    0       0              0
# 2  141.211998  Intel Core i5  Intel Core i5    0  256       0              0
# 3  220.534624  Intel Core i7  Intel Core i7    0  512       0              0
# 4  226.983005  Intel Core i5  Intel Core i5    0  256       0              0
#
#   Gpu brand                 os
# ...

# %%
df["Cpu name"].value_counts()
# Out:
# Cpu name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A6-Series A6-9220         2
# AMD A10-Series 9600P          2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# ...

# %%
{i:key for key , i in enumerate(list(df['Cpu name'].unique()))}
# Out:
# {'Intel Core i5': 0,
#  'Intel Core i7': 1,
#  'AMD A9-Series 9420': 2,
#  'Intel Core i3': 3,
#  'Intel Core M': 4,
#  'Intel Atom x5-Z8350': 5,
#  'AMD E-Series E2-9000e': 6,
#  'Intel Atom x5-Z8300': 7,
#  'AMD E-Series E2-6110': 8,
#  'AMD A6-Series 9220': 9,
#  'Intel Celeron Dual': 10,
#  'AMD Ryzen 1700': 11,
#  'Intel Pentium Quad': 12,
#  'Intel Atom x5-Z8550': 13,
#  'AMD FX 9830P': 14,
#  'AMD E-Series 6110': 15,
#  'Intel Xeon E3-1505M': 16,
#  'AMD E-Series 9000e': 17,
#  'AMD A10-Series A10-9620P': 18,
#  'AMD A6-Series A6-9220': 19,
#  'AMD A10-Series 9600P': 20,
#  'AMD A8-Series 7410': 21,
#  'AMD A12-Series 9720P': 22,
#  'Intel Celeron Quad': 23,
#  'AMD Ryzen 1600': 24,
#  'AMD A10-Series 9620P': 25,
#  'AMD E-Series 7110': 26,
#  'AMD A9-Series A9-9420': 27,
#  'Intel Xeon E3-1535M': 28,
#  'AMD E-Series E2-9000': 29,
#  'AMD A6-Series 7310': 30,
#  'Intel Atom Z8350': 31,
#  'Intel Pentium Dual': 32,
#  'AMD A12-Series 9700P': 33,
#  'AMD A4-Series 7210': 34,
# ...

# %%
dt4 = {'Intel Core i5': 0,
 'Intel Core i7': 1,
 'AMD A9-Series 9420': 2,
 'Intel Core i3': 3,
 'Intel Core M': 4,
 'Intel Atom x5-Z8350': 5,
 'AMD E-Series E2-9000e': 6,
 'Intel Atom x5-Z8300': 7,
 'AMD E-Series E2-6110': 8,
 'AMD A6-Series 9220': 9,
 'Intel Celeron Dual': 10,
 'AMD Ryzen 1700': 11,
 'Intel Pentium Quad': 12,
 'Intel Atom x5-Z8550': 13,
 'AMD FX 9830P': 14,
 'AMD E-Series 6110': 15,
 'Intel Xeon E3-1505M': 16,
 'AMD E-Series 9000e': 17,
 'AMD A10-Series A10-9620P': 18,
 'AMD A6-Series A6-9220': 19,
 'AMD A10-Series 9600P': 20,
 'AMD A8-Series 7410': 21,
 'AMD A12-Series 9720P': 22,
 'Intel Celeron Quad': 23,
 'AMD Ryzen 1600': 24,
 'AMD A10-Series 9620P': 25,
 'AMD E-Series 7110': 26,
 'AMD A9-Series A9-9420': 27,
 'Intel Xeon E3-1535M': 28,
 'AMD E-Series E2-9000': 29,
 'AMD A6-Series 7310': 30,
 'Intel Atom Z8350': 31,
 'Intel Pentium Dual': 32,
 'AMD A12-Series 9700P': 33,
 'AMD A4-Series 7210': 34,
 'AMD FX 8800P': 35,
 'Intel Atom X5-Z8350': 36,
 'AMD E-Series 9000': 37,
 'AMD A9-Series 9410': 38}

# %%
df['Cpu name'] = df['Cpu name'].map(dt4)

# %%
{i:key for key , i in enumerate(list(df['Cpu brand'].unique()))}
# Out:
# {'Intel Core i5': 0,
#  'Intel Core i7': 1,
#  'AMD processor': 2,
#  'Intel Core i3': 3,
#  'Other intel processor': 4}

# %%
dt5 = {'Intel Core i5': 0,
 'Intel Core i7': 1,
 'AMD processor': 2,
 'Intel Core i3': 3,
 'Other intel processor': 4}

# %%
df["Cpu brand"]=df["Cpu brand"].map(dt5)

# %%
df['Cpu brand'].value_counts()
# Out:
# Cpu brand
# 1    527
# 0    423
# 4    154
# 3    136
# 2     62
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Company  TypeName  Cpu  Ram  Memory  Weight        Price  Touchscreen  IPS  \
# 0        0         0    0    8       0    1.37   71378.6832            0    1
# 1        0         0    1    8       1    1.34   47895.5232            0    0
# 2        1         1    2    8       2    1.86   30636.0000            0    0
# 3        0         0    3   16       3    1.83  135195.3360            0    1
# 4        0         0    4    8       2    1.37   96095.8080            0    1
#
#           ppi  Cpu name  Cpu brand  HDD  SSD  Hybrid  Flash_Storage Gpu brand  \
# 0  226.983005         0          0    0  128       0              0     Intel
# 1  127.677940         0          0    0    0       0              0     Intel
# 2  141.211998         0          0    0  256       0              0     Intel
# 3  220.534624         1          1    0  512       0              0       AMD
# 4  226.983005         0          0    0  256       0              0     Intel
#
#                   os
# ...

# %%
{i:key for key , i in enumerate(list(df['Gpu brand'].unique()))}
# Out:
# {'Intel': 0, 'AMD': 1, 'Nvidia': 2}

# %%
dt6 = {'Intel': 0, 'AMD': 1, 'Nvidia': 2}

# %%
df["Gpu brand"]=df["Gpu brand"].map(dt6)

# %%
{i:key for key , i in enumerate(list(df['os'].unique()))}
# Out:
# {'Mac': 0, 'Other/no os/Linus': 1, 'Windows': 2}

# %%
dt7 = {'Mac': 0, 'Other/no os/Linus': 1, 'Windows': 2}

# %%
df["os"]=df["os"].map(dt7)

# %%
# !pip install scikit-learn
# # from sklearn.compose import ColumnTransformer
# # from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.metrics import r2_score, mean_absolute_error
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder

# %%
# !pip install xgboost
# from sklearn.linear_model import LinearRegression,Ridge,Lasso
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestClassifier,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
# from sklearn.svm import SVR
# from xgboost import XGBRegressor

# %%
# from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error
# from sklearn.linear_model import LinearRegression,Ridge,Lasso
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
# from sklearn.svm import SVR
from xgboost import XGBRegressor
# from sklearn.model_selection import train_test_split

# %%
# from sklearn.preprocessing import OneHotEncoder
# print("done")

# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(drop='first'),[0,1,7,10,11])
# ],remainder='passthrough')

# step2 = LinearRegression()

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])
X
# Out:
#       Company  TypeName  Cpu  Ram  Memory  Weight  Touchscreen  IPS  \
# 0           0         0    0    8       0    1.37            0    1
# 1           0         0    1    8       1    1.34            0    0
# 2           1         1    2    8       2    1.86            0    0
# 3           0         0    3   16       3    1.83            0    1
# 4           0         0    4    8       2    1.37            0    1
# ...       ...       ...  ...  ...     ...     ...          ...  ...
# 1298        5         4   44    4       0    1.80            1    1
# 1299        5         4   44   16       3    1.30            1    1
# 1300        5         1   85    2      10    1.50            0    0
# 1301        1         1   44    6       6    2.19            0    0
# 1302        3         1   85    4       4    2.20            0    0
#
#              ppi  Cpu name  Cpu brand   HDD  SSD  Hybrid  Flash_Storage  \
# 0     226.983005         0          0     0  128       0              0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.7524696667160045

# %%
lr.score(X_test,y_test)
# Out:
# 0.7599464135058356

# %%
pred = lr.predict(X_test)

# %%
# check your predictions 
compare_df = pd.DataFrame({"actual":y_test.values,"prediction":pred})
compare_df.head(30)
# Out:
#        actual  prediction
# 0   10.490274   10.749154
# 1    9.387207    9.747877
# 2    9.964522   10.132565
# 3   10.111883   10.629317
# 4   11.470547   10.880260
# 5   11.503355   11.361986
# 6   10.082584   10.196950
# 7   10.301710   10.454538
# 8   11.058781   10.932263
# 9    9.581363   10.114785
# 10  11.511925   10.768146
# 11  10.765658   11.023930
# 12  11.328643   11.304948
# 13  10.729081   11.095694
# 14  11.501201   11.703174
# 15  10.776844   11.057160
# 16  11.193738   10.746061
# 17   9.317895    9.715835
# 18  11.622622   11.322796
# 19  11.470547   11.628682
# 20  11.555699   11.414749
# 21  11.583439   11.244751
# 22  10.658922   10.917938
# 23  10.908984   11.414726
# 24  10.301710   10.687607
# 25  11.497961   11.934931
# 26  10.860048   10.941291
# 27   9.830633   10.088559
# 28  11.129965   11.208696
# 29  10.891800   10.832273

# %%
print('R2 score',r2_score(y_test,pred))
print('MAE',mean_absolute_error(y_test,pred))
# Out:
# R2 score 0.7599464135058356
# MAE 0.2401650117939364

# %%
Xr = XGBRegressor()

# %%
Xr.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
Xr.score(X_train,y_train)
# Out:
# 0.9940935925327229

# %%
Xr.score(X_test,y_test)
# Out:
# 0.8945723950870577

# %% [markdown]
# ### exporting model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[139], line 4
#       2 from sklearn.pipeline import Pipeline
#       3 pickle.dump(df,open('df.pkl','wb'))
# ----> 4 pickle.dump(pipe,open('pipe.pkl','wb'))
#
# NameError: name 'pipe' is not defined

# %%
import pickle
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Define the pipeline
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression())
])

# Save the DataFrame and pipeline
pickle.dump(df, open('df.pkl', 'wb'))
pickle.dump(pipe, open('pipe.pkl', 'wb'))
